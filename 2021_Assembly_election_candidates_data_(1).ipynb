# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhodip1/CURD-OPERATION-IN-JAVA-AND-JDBC/blob/main/2021_Assembly_election_candidates_data_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files   #to upload files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1af9c436-dd47-487d-8bbf-bbbe4c9cb1a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1af9c436-dd47-487d-8bbf-bbbe4c9cb1a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd   #import panda

# %%
wb_result = pd.read_csv("west_bengal.csv")
print(wb_result)
# Out:
#                 candidate         constituency   party  criminal_cases  \
# 0        Abdul Hai Mallik                 ONDA     IND               0
# 1      Abdur Razzak Molla                FALTA     INC               2
# 2    Abhijit Bhattacharya              PURULIA     IND               0
# 3     Abir Chandra Mandal              CHHATNA     IND               0
# 4        Adhikari Suvendu            NANDIGRAM     BJP               1
# ..                    ...                  ...     ...             ...
# 562          Uttam Naskar       BISHNUPUR (SC)     IND               0
# 563   Uttara Singha Hazra              GARBETA    AITC               1
# 564    Vibekananda Mondal  ULUBERIA UTTAR (SC)     IND               0
# 565     Vivekananda Bauri    RAGHUNATHPUR (SC)     BJP               0
# 566    Yamini Kanta Mandi        MANBAZAR (ST)  CPI(M)               0
#
#                  education  total_assets  liabilities
# 0                 8th Pass        160171            0
# ...

# %%
wb_result.head(30)    # print 1st 30
# Out:
#                candidate      constituency                party  \
# 0       Abdul Hai Mallik              ONDA                  IND
# 1     Abdur Razzak Molla             FALTA                  INC
# 2   Abhijit Bhattacharya           PURULIA                  IND
# 3    Abir Chandra Mandal           CHHATNA                  IND
# 4       Adhikari Suvendu         NANDIGRAM                  BJP
# 5      Adhikary Nilanjan        NANDAKUMAR                  BJP
# 6     Aditya Kumar Bauri      SALTORA (SC)  Bahujan Mukti Party
# 7          Aditya Mahato           PURULIA                  IND
# 8           Aditya Manik          KHANAKUL                  IND
# 9        Agniswar Naskar    BISHNUPUR (SC)                  BJP
# 10        Ahammad Sardar  MAGRAHAT PASCHIM              SUCI(C)
# 11           Ajay Haldar     CANNING PURBA                  IND
# 12             Ajit Baul  BARUIPUR PASCHIM                  BSP
# 13            Ajit Maity            PINGLA                 AITC
# ...

# %%
wb_result.tail(30)    # print last 30
# Out:
#                      candidate         constituency  \
# 537          Tapan Kumar Ghosh              GARBETA
# 538          Tapan Kumar Maity           MAHISHADAL
# 539               Tapan Mistri          GOSABA (SC)
# 540         Tapas Kumar Mishra              GARBETA
# 541                Tapas Sinha          NARAYANGARH
# 542              Tapasi Mondal          HALDIA (SC)
# 543                 Tarani Roy              BARJORA
# 544       Tarapada Chakrabarti                 ONDA
# 545         Tarun Kanti Naskar        JAYNAGAR (SC)
# 546          Tarun Kumar Ghosh            MEDINIPUR
# 547           Tarun Kumar Jana         KANTHI UTTAR
# 548          Tarun Kumar Maity                 EGRA
# 549               Tarun Mandal       PANSKURA PURBA
# 550            Tikaram Hembram         BANDWAN (ST)
# 551    Tilak Kumar Chakraborty           MAHISHADAL
# 552         Tirtha Nath Mahato               JOYPUR
# 553        Tnusree Chakraborty             SHYAMPUR
# ...

# %%
wb_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   candidate       567 non-null    object
#  1   constituency    567 non-null    object
#  2   party           567 non-null    object
#  3   criminal_cases  567 non-null    int64
#  4   education       567 non-null    object
#  5   total_assets    567 non-null    int64
#  6   liabilities     567 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 31.1+ KB

# %%
wb_result.describe()
# Out:
#        criminal_cases  total_assets   liabilities
# count      567.000000  5.670000e+02  5.670000e+02
# mean         0.839506  7.109702e+06  8.508290e+05
# std          2.467597  2.341999e+07  3.407338e+06
# min          0.000000  0.000000e+00  0.000000e+00
# 25%          0.000000  3.652070e+05  0.000000e+00
# 50%          0.000000  1.743550e+06  0.000000e+00
# 75%          1.000000  5.911767e+06  2.540000e+05
# max         27.000000  4.302504e+08  4.268688e+07

# %%
wb_result.shape   #print the shape (row and column)
# Out:
# (567, 7)

# %%
wb_result.values      #convert values into array
# Out:
# array([['Abdul Hai Mallik', 'ONDA', 'IND', ..., '8th Pass', 160171, 0],
#        ['Abdur Razzak Molla', 'FALTA', 'INC', ..., '10th Pass', 2650450,
#         0],
#        ['Abhijit Bhattacharya', 'PURULIA', 'IND', ..., 'Post Graduate',
#         4439532, 375000],
#        ...,
#        ['Vibekananda Mondal', 'ULUBERIA UTTAR (SC)', 'IND', ...,
#         '12th Pass', 11953, 0],
#        ['Vivekananda Bauri', 'RAGHUNATHPUR (SC)', 'BJP', ...,
#         'Graduate Professional', 2030856, 0],
#        ['Yamini Kanta Mandi', 'MANBAZAR (ST)', 'CPI(M)', ...,
#         'Post Graduate', 3396148, 1000000]], dtype=object)

# %%
wb_resultsort= wb_result.sort_values('education',ascending=True)  #sort acconding education in ascending order
wb_resultsort.head(30)
# Out:
#                 candidate         constituency  \
# 166           Dipen Bauri         SALTORA (SC)
# 130       Chiranjit Barik             PURSURAH
# 132     D. Madhusudan Rao      KHARAGPUR SADAR
# 140       Deblina Hembram       RANIBANDH (ST)
# 466        Somnath Sarkar  MAGRAHAT PURBA (SC)
# 465        Somnath Mondal                FALTA
# 146            Deepak Ram                FALTA
# 128           Chiran Bera  ULUBERIA UTTAR (SC)
# 148  Dhruba Sekhar Mandal               DASPUR
# 156           Dilip Yadav             PURSURAH
# 458        Sk. Hasimuddin              BANKURA
# 454            Sk Rabiyal           SATGACHHIA
# 450        Sitaram Hansda           BALARAMPUR
# 446    Sisir Kumar Mondal     MANDIRBAZAR (SC)
# 180         Ghosh Susanta              SALBONI
# 152  Dibya Joti Singh Deo               JOYPUR
# 187     Gouri Sing Sardar        MANBAZAR (ST)
# 127        Chinmay Naskar  BARUIPUR PURBA (SC)
# 124       Chandan Samanta             KHANAKUL
# ...

# %%
wb_result.ind=wb_result.sort_values('total_assets')
wb_result.ind.tail()
# Out:
# <ipython-input-13-be972bfd4c37>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   wb_result.ind=wb_result.sort_values('total_assets')
#               candidate      constituency party  criminal_cases  \
# 48     Arup Chakraborty         TALDANGRA  AITC               0
# 24   Ambujaksha Mahanti         PATASHPUR   BJP               0
# 164       Dipankar Jana           KAKDWIP   BJP               2
# 90        Bharati Ghosh             DEBRA   BJP              19
# 396  Samsul Huda Laskar  MAGRAHAT PASCHIM   IND               0
#
#                  education  total_assets  liabilities
# 48   Graduate Professional      88251416     39858383
# 24   Graduate Professional     107021114            0
# 164               Graduate     144192077     42686883
# 90           Post Graduate     192113310      7798626
# 396          Post Graduate     430250365     15000000
# ...

# %%
wb_result.ind.head()
# Out:
#             candidate constituency    party  criminal_cases  education  \
# 29        Anandi Tudu   BALARAMPUR      BSP               0  10th Pass
# 89   Bhagirath Mahato       JOYPUR  SUCI(C)               0  12th Pass
# 264      Manas Sardar      PURULIA      BSP               0   8th Pass
# 160       Dipak Kumar   BALARAMPUR  SUCI(C)               0  12th Pass
# 359        Rajib Mudi  BINPUR (ST)  SUCI(C)               0   Graduate
#
#      total_assets  liabilities
# 29              0            0
# 89              0            0
# 264             0            0
# 160             0            0
# 359           500            0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6681170894110823188 = autoviz.get_df('df_6681170894110823188')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
# ...

# %%
wb_result.ind.to_string()
# Out:
# '                        candidate          constituency                            party  criminal_cases              education  total_assets  liabilities\n29                    Anandi Tudu            BALARAMPUR                              BSP               0              10th Pass             0            0\n89               Bhagirath Mahato                JOYPUR                          SUCI(C)               0              12th Pass             0            0\n264                  Manas Sardar               PURULIA                              BSP               0               8th Pass             0            0\n160                   Dipak Kumar            BALARAMPUR                          SUCI(C)               0              12th Pass             0            0\n359                    Rajib Mudi           BINPUR (ST)                          SUCI(C)               0               Graduate           500            0\n525            Swapan Kumar Murmu         MANBAZAR (ST)      
# ...

# %%
dataf = pd.DataFrame(wb_result.ind, columns=['candidate', 'liabilities	',
                                     'criminal_cases', 'total_assets'])
dataf
# Out:
#               candidate  liabilities\t  criminal_cases  total_assets
# 29          Anandi Tudu            NaN               0             0
# 89     Bhagirath Mahato            NaN               0             0
# 264        Manas Sardar            NaN               0             0
# 160         Dipak Kumar            NaN               0             0
# 359          Rajib Mudi            NaN               0           500
# ..                  ...            ...             ...           ...
# 48     Arup Chakraborty            NaN               0      88251416
# 24   Ambujaksha Mahanti            NaN               0     107021114
# 164       Dipankar Jana            NaN               2     144192077
# 90        Bharati Ghosh            NaN              19     192113310
# 396  Samsul Huda Laskar            NaN               0     430250365
#
# [567 rows x 4 columns]

# %%
candidate=wb_result['criminal_cases']
candidate.head(50)
# Out:
# 0     0
# 1     2
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     0
# 8     0
# 9     1
# 10    0
# 11    0
# 12    0
# 13    1
# 14    0
# 15    1
# 16    0
# 17    0
# 18    0
# 19    0
# 20    1
# 21    0
# 22    0
# 23    6
# 24    0
# 25    2
# 26    0
# 27    1
# 28    0
# 29    0
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# 35    0
# 36    0
# 37    3
# 38    0
# 39    0
# 40    4
# 41    0
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    1
# 48    0
# 49    1
# Name: criminal_cases, dtype: int64

# %%
candidate=wb_result['candidate']
candidate.head(50)
# Out:
# 0          Abdul Hai Mallik
# 1        Abdur Razzak Molla
# 2      Abhijit Bhattacharya
# 3       Abir Chandra Mandal
# 4          Adhikari Suvendu
# 5         Adhikary Nilanjan
# 6        Aditya Kumar Bauri
# 7             Aditya Mahato
# 8              Aditya Manik
# 9           Agniswar Naskar
# 10           Ahammad Sardar
# 11              Ajay Haldar
# 12                Ajit Baul
# 13               Ajit Maity
# 14                 Ajit Ray
# 15               Akhil Giri
# 16              Akshay Khan
# 17            Akshay Santra
# 18     Akshaya Kumar Mahata
# 19           Alok Mukherjee
# 20            Aloke Jaldata
# 21              Aloke Koley
# 22        Amal Kumar Barman
# 23          Amarnath Shakha
# 24       Ambujaksha Mahanti
# 25     Amitabha Chakraborti
# 26            Amitav Naskar
# 27             Amulya Maity
# 28             Ananda Kundu
# 29              Anandi Tudu
# 30              Anath Bauri
# 31      Anil Chandra Mondal
# 32           Animesh Mahata
# ...

# %%
wb_resultsort= wb_result.sort_values('total_assets',ascending=True) #sort acconding total_assets in ascending order
wb_resultsort.tail()
# Out:
#               candidate      constituency party  criminal_cases  \
# 48     Arup Chakraborty         TALDANGRA  AITC               0
# 24   Ambujaksha Mahanti         PATASHPUR   BJP               0
# 164       Dipankar Jana           KAKDWIP   BJP               2
# 90        Bharati Ghosh             DEBRA   BJP              19
# 396  Samsul Huda Laskar  MAGRAHAT PASCHIM   IND               0
#
#                  education  total_assets  liabilities
# 48   Graduate Professional      88251416     39858383
# 24   Graduate Professional     107021114            0
# 164               Graduate     144192077     42686883
# 90           Post Graduate     192113310      7798626
# 396          Post Graduate     430250365     15000000

# %%
wb_resultsort= wb_result.sort_values('criminal_cases',ascending=True) #sort acconding criminal cases in ascending order
wb_resultsort.tail(10)
# Out:
#                    candidate      constituency  \
# 294       Munsi Nazbul Karim          KHANAKUL
# 154        Dilip Kumar Jatua  MANDIRBAZAR (SC)
# 329        Partha Pratim Das      KHEJURI (SC)
# 139            Debjit Sarkar         JANGIPARA
# 159                Dinen Roy         KHARAGPUR
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases              education  \
# 294                            AITC               9               Graduate
# 154                             BJP               9              12th Pass
# 329                            AITC              10  Graduate Professional
# 139                             BJP              11  Graduate Professional
# ...

# %%
wb_resultsort= wb_result.sort_values('education',ascending=True)    #sort acconding education in ascending order
wb_resultsort.tail()
# Out:
#                    candidate   constituency                           party  \
# 179  Gazi Shahabuddin Siraji  CANNING PURBA  Rashtriya Secular Majlis Party
# 445       Sishir Kumar Manna         PINGLA                         SUCI(C)
# 447        Sisir Kumar Patra         DANTAN                             CPI
# 94        Bikash Chandra Das      CHANDIPUR     West Bengal Socialist Party
# 566       Yamini Kanta Mandi  MANBAZAR (ST)                          CPI(M)
#
#      criminal_cases      education  total_assets  liabilities
# 179               0  Post Graduate        234253       169423
# 445               0  Post Graduate       1245000            0
# 447               0  Post Graduate       3521478      1887050
# 94                0  Post Graduate       1713769      1036577
# 566               0  Post Graduate       3396148      1000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
wb_resultsort= wb_result.sort_values('liabilities',ascending=True)    #sort acconding liabilities in ascending order
wb_resultsort.tail()
# Out:
#                   candidate constituency party  criminal_cases  \
# 56             Ashoke Dinda        MOYNA   BJP               0
# 421  Saumen Kumar Mahapatra       TAMLUK  AITC               3
# 518    Swadesh Ranjan Nayak     RAMNAGAR   BJP               7
# 48         Arup Chakraborty    TALDANGRA  AITC               0
# 164           Dipankar Jana      KAKDWIP   BJP               2
#
#                  education  total_assets  liabilities
# 56                Graduate      75063577     18865905
# 421              Doctorate      82825747     19300000
# 518               8th Pass       9950000     22857987
# 48   Graduate Professional      88251416     39858383
# 164               Graduate     144192077     42686883
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1735985003283963860 = autoviz.get_df('df_1735985003283963860')
#
# ...
